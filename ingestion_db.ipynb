# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from sqlalchemy import create_engine, inspect
import sqlite3

db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/begin_inventory.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'begin_inventory'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [begin_inventory] Inserted chunk 1 (500 rows)
# [begin_inventory] Inserted chunk 2 (500 rows)
# [begin_inventory] Inserted chunk 3 (500 rows)
# [begin_inventory] Inserted chunk 4 (500 rows)
# [begin_inventory] Inserted chunk 5 (500 rows)
# [begin_inventory] Inserted chunk 6 (500 rows)
# [begin_inventory] Inserted chunk 7 (500 rows)
# [begin_inventory] Inserted chunk 8 (500 rows)
# [begin_inventory] Inserted chunk 9 (500 rows)
# [begin_inventory] Inserted chunk 10 (500 rows)
# [begin_inventory] Inserted chunk 11 (500 rows)
# [begin_inventory] Inserted chunk 12 (500 rows)
# [begin_inventory] Inserted chunk 13 (500 rows)
# [begin_inventory] Inserted chunk 14 (500 rows)
# [begin_inventory] Inserted chunk 15 (500 rows)
# [begin_inventory] Inserted chunk 16 (500 rows)
# [begin_inventory] Inserted chunk 17 (500 rows)
# ...

# %%
db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/end_inventory.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'end_inventory'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# [end_inventory] Inserted chunk 1 (500 rows)
# [end_inventory] Inserted chunk 2 (500 rows)
# [end_inventory] Inserted chunk 3 (500 rows)
# [end_inventory] Inserted chunk 4 (500 rows)
# [end_inventory] Inserted chunk 5 (500 rows)
# [end_inventory] Inserted chunk 6 (500 rows)
# [end_inventory] Inserted chunk 7 (500 rows)
# [end_inventory] Inserted chunk 8 (500 rows)
# [end_inventory] Inserted chunk 9 (500 rows)
# [end_inventory] Inserted chunk 10 (500 rows)
# [end_inventory] Inserted chunk 11 (500 rows)
# [end_inventory] Inserted chunk 12 (500 rows)
# [end_inventory] Inserted chunk 13 (500 rows)
# [end_inventory] Inserted chunk 14 (500 rows)
# [end_inventory] Inserted chunk 15 (500 rows)
# [end_inventory] Inserted chunk 16 (500 rows)
# [end_inventory] Inserted chunk 17 (500 rows)
# [end_inventory] Inserted chunk 18 (500 rows)
# [end_inventory] Inserted chunk 19 (500 rows)
# [end_inventory] Inserted chunk 20 (500 rows)
# [end_inventory] Inserted chunk 21 (500 rows)
# ...

# %%
db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/purchase_prices.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'purchase_prices'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# [purchase_prices] Inserted chunk 1 (500 rows)
# [purchase_prices] Inserted chunk 2 (500 rows)
# [purchase_prices] Inserted chunk 3 (500 rows)
# [purchase_prices] Inserted chunk 4 (500 rows)
# [purchase_prices] Inserted chunk 5 (500 rows)
# [purchase_prices] Inserted chunk 6 (500 rows)
# [purchase_prices] Inserted chunk 7 (500 rows)
# [purchase_prices] Inserted chunk 8 (500 rows)
# [purchase_prices] Inserted chunk 9 (500 rows)
# [purchase_prices] Inserted chunk 10 (500 rows)
# [purchase_prices] Inserted chunk 11 (500 rows)
# [purchase_prices] Inserted chunk 12 (500 rows)
# [purchase_prices] Inserted chunk 13 (500 rows)
# [purchase_prices] Inserted chunk 14 (500 rows)
# [purchase_prices] Inserted chunk 15 (500 rows)
# [purchase_prices] Inserted chunk 16 (500 rows)
# [purchase_prices] Inserted chunk 17 (500 rows)
# [purchase_prices] Inserted chunk 18 (500 rows)
# [purchase_prices] Inserted chunk 19 (500 rows)
# [purchase_prices] Inserted chunk 20 (500 rows)
# ...

# %%
db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/purchases.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'purchases'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# [purchases] Inserted chunk 1 (500 rows)
# [purchases] Inserted chunk 2 (500 rows)
# [purchases] Inserted chunk 3 (500 rows)
# [purchases] Inserted chunk 4 (500 rows)
# [purchases] Inserted chunk 5 (500 rows)
# [purchases] Inserted chunk 6 (500 rows)
# [purchases] Inserted chunk 7 (500 rows)
# [purchases] Inserted chunk 8 (500 rows)
# [purchases] Inserted chunk 9 (500 rows)
# [purchases] Inserted chunk 10 (500 rows)
# [purchases] Inserted chunk 11 (500 rows)
# [purchases] Inserted chunk 12 (500 rows)
# [purchases] Inserted chunk 13 (500 rows)
# [purchases] Inserted chunk 14 (500 rows)
# [purchases] Inserted chunk 15 (500 rows)
# [purchases] Inserted chunk 16 (500 rows)
# [purchases] Inserted chunk 17 (500 rows)
# [purchases] Inserted chunk 18 (500 rows)
# [purchases] Inserted chunk 19 (500 rows)
# [purchases] Inserted chunk 20 (500 rows)
# [purchases] Inserted chunk 21 (500 rows)
# [purchases] Inserted chunk 22 (500 rows)
# [purchases] Inserted chunk 23 (500 rows)
# ...

# %%
db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/sales.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'sales'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# [sales] Inserted chunk 20659 (500 rows)
# [sales] Inserted chunk 20660 (500 rows)
# [sales] Inserted chunk 20661 (500 rows)
# [sales] Inserted chunk 20662 (500 rows)
# [sales] Inserted chunk 20663 (500 rows)
# [sales] Inserted chunk 20664 (500 rows)
# [sales] Inserted chunk 20665 (500 rows)
# [sales] Inserted chunk 20666 (500 rows)
# [sales] Inserted chunk 20667 (500 rows)
# [sales] Inserted chunk 20668 (500 rows)
# [sales] Inserted chunk 20669 (500 rows)
# [sales] Inserted chunk 20670 (500 rows)
# [sales] Inserted chunk 20671 (500 rows)
# [sales] Inserted chunk 20672 (500 rows)
# [sales] Inserted chunk 20673 (500 rows)
# [sales] Inserted chunk 20674 (500 rows)
# [sales] Inserted chunk 20675 (500 rows)
# [sales] Inserted chunk 20676 (500 rows)
# [sales] Inserted chunk 20677 (500 rows)
# [sales] Inserted chunk 20678 (500 rows)
# [sales] Inserted chunk 20679 (500 rows)
# [sales] Inserted chunk 20680 (500 rows)
# ...

# %%
db_path = '/content/drive/My Drive/Vendor Performance Analysis/inventory.db'
data_path = '/content/drive/My Drive/Vendor Performance Analysis/data/vendor_invoice.csv'

engine = create_engine(f'sqlite:///{db_path}')

def ingest_vendor_invoice(chunksize=500):
    table_name = 'vendor_invoice'
    inspector = inspect(engine)
    existing_tables = inspector.get_table_names()
    if table_name in existing_tables:
        print(f"Tabel '{table_name}' sudah ada. Proses ingest dihentikan untuk mencegah duplikasi.")
        return
    chunk_num = 0
    for chunk in pd.read_csv(data_path, chunksize=chunksize, low_memory=True):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='append',
            index=False,
            method='multi'
        )
        chunk_num += 1
        print(f"[{table_name}] Inserted chunk {chunk_num} ({len(chunk)} rows)")
    print(f"Ingestion of {table_name} complete!")

ingest_vendor_invoice()

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in DB:", tables)

for table in tables:
    table_name = table[0]
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

conn.close()
# Out:
# [vendor_invoice] Inserted chunk 1 (500 rows)
# [vendor_invoice] Inserted chunk 2 (500 rows)
# [vendor_invoice] Inserted chunk 3 (500 rows)
# [vendor_invoice] Inserted chunk 4 (500 rows)
# [vendor_invoice] Inserted chunk 5 (500 rows)
# [vendor_invoice] Inserted chunk 6 (500 rows)
# [vendor_invoice] Inserted chunk 7 (500 rows)
# [vendor_invoice] Inserted chunk 8 (500 rows)
# [vendor_invoice] Inserted chunk 9 (500 rows)
# [vendor_invoice] Inserted chunk 10 (500 rows)
# [vendor_invoice] Inserted chunk 11 (500 rows)
# [vendor_invoice] Inserted chunk 12 (43 rows)
# Ingestion of vendor_invoice complete!
# Tables in DB: [('begin_inventory',), ('end_inventory',), ('purchase_prices',), ('purchases',), ('sales',), ('vendor_invoice',)]
# begin_inventory: 206529 rows
# end_inventory: 224489 rows
# purchase_prices: 12261 rows
# purchases: 2372474 rows
# sales: 12825363 rows
# vendor_invoice: 5543 rows
